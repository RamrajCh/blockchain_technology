# %%
#
# Distributed Networks - Similated Praceice
#
import multiprocessing

# Define a function that will be executed on a separate process
def process_function(input_data):
    # Perform some computation on the input data
    result = input_data * 2
    print("Process function result:", result,"\n")
    return result

if __name__ == '__main__':
    # Create a process pool with 4 worker processes
    with multiprocessing.Pool(processes=4) as pool:
        # Define the input data for the processes
        input_data = [1, 2, 3, 4]
        # Use the map function to apply the process function to the input data
        results = pool.map(process_function, input_data)
        print("All results:", results)

# In this example, the script creates a process pool with 4 worker processes using the multiprocessing.Pool class. 
# It then defines a function called process_function that takes an input data and performs some computation on it 
# (in this case, it multiplies the input by 2).
# The script then uses the map function of the process pool to apply the process_function to each element 
# of the input data. This is done in parallel across the 4 worker processes, which allows for faster computation times. 
# The results of each process are collected and returned in a list which is printed out.
# Out:
# Process function result:Process function result:Process function result:Process function result:   64 2
#
#
#
#
#
# 8
#
# All results: [2, 4, 6, 8]

# %%
#
# Proof of Work (PoW) Practice
#
# To DO:
# Improve by adding a time limit for finding the nonce, 
# or increasing the difficulty target for better security.
#
import hashlib

# Difficulty target (number of leading zeros in the hash)
# Means that the output of the hash function should have 2 leading zeros
difficulty = 3

# Data to be hashed
data = b"This is test for proof of work simulation."

# Nonce - Number used in live data transmitting services in order to protect against replay attacks and other disruptions
# Find a nonce that meets the difficulty target
# Nonce starting with 0, it will keep increasing and test the hash meets the difficulty target
nonce = 0
while True:
    # Concatenate the data and nonce
    input_data = data + str(nonce).encode()
    print("Data and Nonce Value: ",input_data)
    # Hash the input data
    hashed_data = hashlib.sha256(input_data).hexdigest()
    print("Hash Data :",hashed_data)
    # Check if the hash meets the difficulty target
    if hashed_data[:difficulty] == "0" * difficulty:
        print("Found a valid nonce (Encode Format):", nonce)
        print("Hash:", hashed_data)
        break
    nonce += 1
# It keeps running to get changed hash value until it found the hash value 
# having two leading 0 in the beginning
# Out:
# Data and Nonce Value:  b'This is test for proof of work simulation.0'
# Hash Data : df7141a92e53f7d64a81e058719a78d29d3ab0079ce8319531ba29ff3d54b9de
# Data and Nonce Value:  b'This is test for proof of work simulation.1'
# Hash Data : 93e12ec815a513bbc5fb872042ac23a4c258c329049885c20582ccb78ffc498c
# Data and Nonce Value:  b'This is test for proof of work simulation.2'
# Hash Data : f318d2f5f191c2b1346a028e4ebd67f45b07e405fe9446b21fff6ab920b29847
# Data and Nonce Value:  b'This is test for proof of work simulation.3'
# Hash Data : 744d5bc253f9b93fda14a9f46a2cc29d25bf9adb47a2911d113ff65609d08454
# Data and Nonce Value:  b'This is test for proof of work simulation.4'
# Hash Data : 3a79c9056324b746f71e421036eb65468b360d5ddba6f98c5eda3ab25e94867d
# Data and Nonce Value:  b'This is test for proof of work simulation.5'
# Hash Data : 2295b7c3a2ab0df2ac46e82ca98d305a41be3b1d7050fd6816bb9ef44f6dbe00
# Data and Nonce Value:  b'This is test for proof of work simulation.6'
# Hash Data : 09d1780c29432eef1b00f210c660d875cac8f9adc4160a83b62d50f80bc204cf
# Data and Nonce Value:  b'This is test for proof of work simulation.7'
# Hash Data : ce1c181bab304ba08dd010d1fc8055cd70c650087063fc8cdb9a9fd8bf8c3884
# Data and Nonce Value:  b'This is test for proof of work simulation.8'
# Hash Data : 5ea54c72d91747b91b0736d63a1061107851c8af00e65f3716a9cb2cba4170bc
# Data and Nonce Value:  b'This is test for proof of work simulation.9'
# Hash Data : 66fa9403c5d6e207987bbb837a09c6c52935a625c2ff5dfbfd6d40f11b2ed15a
# Data and Nonce Value:  b'This is test for proof of work simulation.10'
# Hash Data : d7ff2456c9bff5f99eb6b72ce417504df45857df09dc2b1250612654f425516e
# Data and Nonce Value:  b'This is test for proof of work simulation.11'
# Hash Data : ee766c773fab79d6c9dd833ab2d3a4d2a5fe6ac7325b162157d145e22993125a
# Data and Nonce Value:  b'This is test for proof of work simulation.12'
# Hash Data : 1987fa3f62f2d8c0b1a86300057669aa61c624e0b2b1258ca40874a3962abbb8
# Data and Nonce Value:  b'This is test for proof of work simulation.13'
# Hash Data : 268234237c4aff14bfdeb5b2087f98a362f340842ebbb4ae12c41c349e742490
# Data and Nonce Value:  b'This is test for proof of work simulation.14'
# Hash Data : 1ae8f90cec945aa5d169ffb98e6fad450b94ce1fe155d0c05c111d6011444bf5
# Data and Nonce Value:  b'This is test for proof of work simulation.15'
# Hash Data : 3a696714f32a076321676aa63cec10fff32d3331b6dcce48bc2f3e2fe5877221
# Data and Nonce Value:  b'This is test for proof of work simulation.16'
# Hash Data : 921c9627200cc34fbb722d7aefd0fa068f121555eefcb9e76a29e68aac376ae0
# Data and Nonce Value:  b'This is test for proof of work simulation.17'
# Hash Data : af4ee1077dad40abd8a3a83cc7395c8034b134a786989372243770d64b13ef87
# Data and Nonce Value:  b'This is test for proof of work simulation.18'
# Hash Data : df76bd8cb805e166b9abab7580d89e48f6c60a021b167925454eb6ff7754c94c
# Data and Nonce Value:  b'This is test for proof of work simulation.19'
# Hash Data : c61f38ad7729cc5d2a73507f6654913793188cd0f2c549f3da399c40b00af927
# Data and Nonce Value:  b'This is test for proof of work simulation.20'
# Hash Data : 9a5b0e530871da61f4a48f4c80356d4a093a43725417a318f9dd2ea7a1a3c5ca
# Data and Nonce Value:  b'This is test for proof of work simulation.21'
# Hash Data : bd6219d27976faa3258d893e07cb76c4211b5c5bb6eb5eef4e0de8c6cafa4435
# Data and Nonce Value:  b'This is test for proof of work simulation.22'
# Hash Data : 7f10c8a1b33663a2612f4222ed8aa3061fdfc0bfef64172584f06ef9dab047a6
# Data and Nonce Value:  b'This is test for proof of work simulation.23'
# Hash Data : c1e2bca3cf71ee5d20423d3265c6885d1c595f925ae2564f5334e4f2ebd840ec
# Data and Nonce Value:  b'This is test for proof of work simulation.24'
# Hash Data : ebfe9b3b8a67651033b4577bb2e6f2b0fa113354a5a1690185b0f9602873d7ed
# Data and Nonce Value:  b'This is test for proof of work simulation.25'
# Hash Data : 8c1d6e99702121ad329b2d59e823caf685cc12a2b7bf7cc3ef5cb54bb2339aee
# Data and Nonce Value:  b'This is test for proof of work simulation.26'
# Hash Data : a544a661c358402e6580386bc925f334ff8f4449f5ab343b3ff5334a66eb6ee4
# Data and Nonce Value:  b'This is test for proof of work simulation.27'
# Hash Data : 99c2d4b8daf946da9c3a3cd4acafc83e04e50f3b5cc651550550a95cf9b651fd
# Data and Nonce Value:  b'This is test for proof of work simulation.28'
# Hash Data : 4333470b14d4241a5f6fbfd2c71419ba5fce09ed9b41ff0b91b61693e5a9715e
# Data and Nonce Value:  b'This is test for proof of work simulation.29'
# Hash Data : cc9df9eb5a757416635c7aeb7544953ed133a88aca371620745b036912de5d98
# Data and Nonce Value:  b'This is test for proof of work simulation.30'
# Hash Data : f2e65af85868db2c7b7026ef52c7a5291842329a7a2bbde914f0c7772e9750c2
# Data and Nonce Value:  b'This is test for proof of work simulation.31'
# Hash Data : 4a0f86aa708d3b914d1b6c83b4976c85265e57a2e174d08b60cd16115b75106f
# Data and Nonce Value:  b'This is test for proof of work simulation.32'
# Hash Data : 9945c730503e0b2a1a2b17f51f40fd65982416b23793b0c6a5888fc4770d6a5f
# Data and Nonce Value:  b'This is test for proof of work simulation.33'
# Hash Data : 944525a60e30fa62432ec27ba2142df1fa2207af84d4df25baee340b8a46d814
# Data and Nonce Value:  b'This is test for proof of work simulation.34'
# Hash Data : e2cbaf9528ecb701d603d656198c97c4ecb2389271ed46eb626f1f7ac41d4e90
# Data and Nonce Value:  b'This is test for proof of work simulation.35'
# Hash Data : 2aa0f724b4f522d6a082d45257b7a8311978e3a178aa077c3f36a107b96dfb4d
# Data and Nonce Value:  b'This is test for proof of work simulation.36'
# Hash Data : 168536242c2d9898d332667050be40884b87a868b11f43fe041f22f51fe1935b
# Data and Nonce Value:  b'This is test for proof of work simulation.37'
# Hash Data : 74835e015816deb840ead2b263ccff6238c03691610063389d75ee128e9dc6ce
# Data and Nonce Value:  b'This is test for proof of work simulation.38'
# Hash Data : e449370955082796a6cb9fec0b4adc9abc18507353bfb31f8ec44d4fc94bc1ac
# Data and Nonce Value:  b'This is test for proof of work simulation.39'
# Hash Data : 5f8c5ba4e9c6907187f92a8b0e000fec3e745667d39769d6f0bb20992ccc4ecf
# Data and Nonce Value:  b'This is test for proof of work simulation.40'
# Hash Data : 5293ea03cea4b1b823487db328ce7a7d70217d2022bd1dbd2970616901d3278f
# Data and Nonce Value:  b'This is test for proof of work simulation.41'
# Hash Data : 384e60051c27588910b590ca5b87b46f0403379d1c3ed552ba3faa79343f7a2e
# Data and Nonce Value:  b'This is test for proof of work simulation.42'
# Hash Data : 38fae3670e525194c31731ca40e7f5f77f3a518b0d379343550230c4d66e1651
# Data and Nonce Value:  b'This is test for proof of work simulation.43'
# Hash Data : c506ab5395dd5ecc7e92595a2dc297d75ab924886698a74745757a697632bb63
# Data and Nonce Value:  b'This is test for proof of work simulation.44'
# Hash Data : 55489e3a6f26ed3868545fcfb838d59684b36c4155a7a7b02ab4ec2cac2bc335
# Data and Nonce Value:  b'This is test for proof of work simulation.45'
# Hash Data : 04d84fba4d6de119ad6cc5838a399f42afe6351eb881cd11feb51cf867431827
# Data and Nonce Value:  b'This is test for proof of work simulation.46'
# Hash Data : f475ecca1809fb3768104ab96a63225441a426f639e68410b93d26e3af63409b
# Data and Nonce Value:  b'This is test for proof of work simulation.47'
# Hash Data : a89f149055102c480501285436acd211f708e4ac5f13470b235f7a1717127d31
# Data and Nonce Value:  b'This is test for proof of work simulation.48'
# Hash Data : 5625277ecc574be871b8afd6eb8c82a434e9946df306f343ac328c1985dd1291
# Data and Nonce Value:  b'This is test for proof of work simulation.49'
# Hash Data : 465e78367b63b568e952819c197c4dc01be69704515eefe9b2291731abe1b13d
# Data and Nonce Value:  b'This is test for proof of work simulation.50'
# Hash Data : 127616c7dc1eaea7bd808838d4dfe8727d41ffa07840f986ce7ff471e33bed4c
# Data and Nonce Value:  b'This is test for proof of work simulation.51'
# Hash Data : 36f421769c4a338b675eca42ef57230310c398627809395b009fff141f4a6be5
# Data and Nonce Value:  b'This is test for proof of work simulation.52'
# Hash Data : 6217598d177238e01ab6c3ada71ab87421ca374553e0bf8615f27c71a9b49891
# Data and Nonce Value:  b'This is test for proof of work simulation.53'
# Hash Data : 47030d7b7a890e95608e4e870ff8e01446274f6d4285615fc091116714e33165
# Data and Nonce Value:  b'This is test for proof of work simulation.54'
# Hash Data : 16675c4e7d873928012ae3907ea6e628e2581112e31aeee39f43aef2d30bbe65
# Data and Nonce Value:  b'This is test for proof of work simulation.55'
# Hash Data : 7f836ec879cbc218fa4ed638bdd5c15f365701c8fa8adbf6f568c8bdd17dc12e
# Data and Nonce Value:  b'This is test for proof of work simulation.56'
# Hash Data : 736cfb62c189a7c19af50d4c298797ac9c67c57a3837f5800d27ee6750684aab
# Data and Nonce Value:  b'This is test for proof of work simulation.57'
# Hash Data : f36706e8f9954cbfd20279b1dff80dcc1036b07ac02c4b6fb980f9af1b548084
# Data and Nonce Value:  b'This is test for proof of work simulation.58'
# Hash Data : 7ae5838eaae25cfeb3251183032aae6014e6ef7b8521768f49e9b85d083fa0b1
# Data and Nonce Value:  b'This is test for proof of work simulation.59'
# Hash Data : 643a2fcb4c83b99763f774f0849e7510168395ea30b8efefb0c02f875d6678dd
# Data and Nonce Value:  b'This is test for proof of work simulation.60'
# Hash Data : 4ca82e220d5004a7e1fb1fe53eb3cef8e175f86077f3bda733193cecc81220b8
# Data and Nonce Value:  b'This is test for proof of work simulation.61'
# Hash Data : 0da024949b9c7231f61cc82a3250e3f7095be22774588b5a47b3b5d59e5f8794
# Data and Nonce Value:  b'This is test for proof of work simulation.62'
# Hash Data : 0dc682167d32ab847a31832b110fe96bb2ab79eed396e397aa4db85172ebf1a5
# Data and Nonce Value:  b'This is test for proof of work simulation.63'
# Hash Data : 29eee49d63ffbbace85017177406df57960cd48a1d680b75ca41d0a46122b0ed
# Data and Nonce Value:  b'This is test for proof of work simulation.64'
# Hash Data : 0fb55de4569773d2edab6c39d8f2ffcd60b1da92e7b525b226d2eded7f073cbf
# Data and Nonce Value:  b'This is test for proof of work simulation.65'
# Hash Data : e52a7b641d6635cc82cf30f32a77f376e07ad95e1167859ba3446dee48fa2bc6
# Data and Nonce Value:  b'This is test for proof of work simulation.66'
# Hash Data : 278d269be41b5adf6c9fc30674ce81805af281f39c2916e89175ff247d10c136
# Data and Nonce Value:  b'This is test for proof of work simulation.67'
# Hash Data : 9db66ff0737eb1cd0ce0624a2d5961bf447752b8bd7988888e8549095b2f8de5
# Data and Nonce Value:  b'This is test for proof of work simulation.68'
# Hash Data : 8c2b77829c0bd2ea612f6b2a4c72f2f90d7b531d0ae5f409c255053fc78e84a5
# Data and Nonce Value:  b'This is test for proof of work simulation.69'
# Hash Data : 575c8052f6ee5cb25ce1272fee2fcc62a98e6669ca6fa4739f351bc3ba967fc9
# Data and Nonce Value:  b'This is test for proof of work simulation.70'
# Hash Data : 0926db38ca5960c5e8ee0e47dc4272bac2f6215c1c941798b20387e510539d2b
# Data and Nonce Value:  b'This is test for proof of work simulation.71'
# Hash Data : bc05db753a2515fc1e590992b69a11fc0fdb7419c60725c157ce8a16a346d9bb
# Data and Nonce Value:  b'This is test for proof of work simulation.72'
# Hash Data : 72045f0e9a2750b49609515d0e5e782c02cd0810759b344c31db68a58465f9af
# Data and Nonce Value:  b'This is test for proof of work simulation.73'
# Hash Data : 6ac49e829af51166ea456bcc7b4900cf76a43f5c27c3318611595e5224ba6878
# Data and Nonce Value:  b'This is test for proof of work simulation.74'
# Hash Data : 72d47c557ac4c1a05c5ed677c683f02b83dad1acce6d6f7c55040c71038fefd0
# Data and Nonce Value:  b'This is test for proof of work simulation.75'
# Hash Data : 8225920eef3e68982286f18b41d3c0a1661b7b43326b92c1b19390b25fe6ae51
# Data and Nonce Value:  b'This is test for proof of work simulation.76'
# Hash Data : 45e60db7b60325b902cf42e4061a87b9af67bb6485e26bc7004573a1980ad86a
# Data and Nonce Value:  b'This is test for proof of work simulation.77'
# Hash Data : 6cea13e0a72825b420342ad10408387b3d794a5dff2f4a949027b98ca10bb90d
# Data and Nonce Value:  b'This is test for proof of work simulation.78'
# Hash Data : 7cfb6446abbd23d96ea87b286516e0d9484b218c39c82f69c24a70ac8742961e
# Data and Nonce Value:  b'This is test for proof of work simulation.79'
# Hash Data : 45b4144fddbf02df3513849c447c1dc82bd2f0a3f5d71743c2c1dfa16f125189
# Data and Nonce Value:  b'This is test for proof of work simulation.80'
# Hash Data : a4f7432601e4b9dae13939282d2e7e89483074774a50c138f3df3a96d3986a31
# Data and Nonce Value:  b'This is test for proof of work simulation.81'
# Hash Data : fcbdddba101426bf9abe65c554f5297e1be0372b36a241aa932d94cbfffa8330
# Data and Nonce Value:  b'This is test for proof of work simulation.82'
# Hash Data : ba9557300348ab51a02e25afbc07486c3ecd539c0b0a9af93a5003897dabff4a
# Data and Nonce Value:  b'This is test for proof of work simulation.83'
# Hash Data : 0b1df20c4304caaf87d96ca2b266f89c62c7421edfabc6fdfa5a1ab59daef75c
# Data and Nonce Value:  b'This is test for proof of work simulation.84'
# Hash Data : 08d3ea7afd14c60c251438d6ffad65a3c0b1ae04e47794feeb9d043a521c0c8e
# Data and Nonce Value:  b'This is test for proof of work simulation.85'
# Hash Data : 516031f45854ccefe7e0910f715ec5be4c3e560f4a5d2dd1d7ee7bfb6c87af46
# Data and Nonce Value:  b'This is test for proof of work simulation.86'
# Hash Data : fba0540553d7a33feab112d43a486b6cb8a63dae5f3fe1821976f0605b96be11
# Data and Nonce Value:  b'This is test for proof of work simulation.87'
# Hash Data : 61effd0047c82ea2a9624c8631203f8aea9e10806967631597f9262a13310a54
# Data and Nonce Value:  b'This is test for proof of work simulation.88'
# Hash Data : 451ad245071a971a698c76a506a58efa1a9b1dc7a27e579296107d9fe950afa8
# Data and Nonce Value:  b'This is test for proof of work simulation.89'
# Hash Data : 0b063ee25a808d1f38737d4a2072a65569bbcf17ce99c1cd30b328eb25fe0542
# Data and Nonce Value:  b'This is test for proof of work simulation.90'
# Hash Data : f08fab57548b3da84bf560cc952f7bf5142c4255b0102966f9d60360699df119
# Data and Nonce Value:  b'This is test for proof of work simulation.91'
# Hash Data : cd4d97924c288a1e50749c372570244d57485d162ef745e6de283cae4bb95b72
# Data and Nonce Value:  b'This is test for proof of work simulation.92'
# Hash Data : 94e92d03481f37902dc5cf4f23c03061f08998b7de62af540e2d65a25586c892
# Data and Nonce Value:  b'This is test for proof of work simulation.93'
# Hash Data : d12aa2745d1e52c3a352f39e95feb729c86ae8eb0c7bc2cc08d54e2cd7055cb5
# Data and Nonce Value:  b'This is test for proof of work simulation.94'
# Hash Data : 8675aa8c1d79e463b03e7783516fd611f70e43457767ec5210bc97aa79915f59
# Data and Nonce Value:  b'This is test for proof of work simulation.95'
# Hash Data : 5296f2892ad3faa5fcace132902f7769e43a3ca35769054696a82bbb836c69fe
# Data and Nonce Value:  b'This is test for proof of work simulation.96'
# Hash Data : 8a59e7a25dd0078a6eaccfe567e6f25c094e80e84108c86444c98e43fb0fe4c6
# Data and Nonce Value:  b'This is test for proof of work simulation.97'
# Hash Data : 176531f24db5eff70b9b5bf515f4c600d8c97f10b4a0d7e7fee2a02800dbcb70
# Data and Nonce Value:  b'This is test for proof of work simulation.98'
# Hash Data : e6936e68a56b7ddb8baf0ab3e3b54e331cab3937229bdcb160f803b929c10f84
# Data and Nonce Value:  b'This is test for proof of work simulation.99'
# Hash Data : d352f590bf97286d398118818c241f71e0f6f29e68d3ef17b9e239f4971aad70
# Data and Nonce Value:  b'This is test for proof of work simulation.100'
# Hash Data : 3f7ec58d3742818137854b25951fb528bd25d387946596ab421c4bea4c4c0150
# Data and Nonce Value:  b'This is test for proof of work simulation.101'
# Hash Data : 4bac22be8ae5d8acb030d8eaca8834c92967494443e1f844f07d5e4be37243c9
# Data and Nonce Value:  b'This is test for proof of work simulation.102'
# Hash Data : 84eac7ff6e8d97300cdbef2e45f3af17bc9a916717cb81e29023c650d4935ef2
# Data and Nonce Value:  b'This is test for proof of work simulation.103'
# Hash Data : 29e5f8d21cea65aebb91589fee718f3e31d8a010eb5b342edf8b992cf671ad3f
# Data and Nonce Value:  b'This is test for proof of work simulation.104'
# Hash Data : c8e2c7a222fed636729fdff9b3b4b40add0e61b88483e2abad3e1f4a7a0a6b85
# Data and Nonce Value:  b'This is test for proof of work simulation.105'
# Hash Data : d30a7a102aeff7f7de433da7e9d06d34885b1d14a0a331ceda4c5d194ab0792c
# Data and Nonce Value:  b'This is test for proof of work simulation.106'
# Hash Data : c51fce311de40d4498d9c187ae57c8002932204f077169d652012e874ea9874f
# Data and Nonce Value:  b'This is test for proof of work simulation.107'
# Hash Data : 737ea2c3e15d559ac42fc9cad832b8d2594d9f6c9ca3651916844f8f640d0c88
# Data and Nonce Value:  b'This is test for proof of work simulation.108'
# Hash Data : 482ccc61f60f03f7591578c1a7b59e9af2b52307151216af7c170e6452951f32
# Data and Nonce Value:  b'This is test for proof of work simulation.109'
# Hash Data : 9119e5cfede3b73dfcc017059a063579bdd9681f79a4584dfc358d8fdde899cb
# Data and Nonce Value:  b'This is test for proof of work simulation.110'
# Hash Data : 4937464dc840b0b3b89f1122666ec165f037109365bb1fe8417f6f1df6ee2651
# Data and Nonce Value:  b'This is test for proof of work simulation.111'
# Hash Data : 9ec79a1240235d77fc759dc650144802944bc1d6075d8e0a36d1e12ae480e74e
# Data and Nonce Value:  b'This is test for proof of work simulation.112'
# Hash Data : 35716283b358928052fd0d523059cd2a35fdb715a8bc2e6594a3dbe5c3316566
# Data and Nonce Value:  b'This is test for proof of work simulation.113'
# Hash Data : fb077167967f9b5d9f9f8bfcf3a7d212e741c62de7a6fa2208967cdf0444b7d0
# Data and Nonce Value:  b'This is test for proof of work simulation.114'
# Hash Data : 128de6329d6cb2d8fcdc483f9147c8758d8ec8f0922d349a0b0f36924ec0e247
# Data and Nonce Value:  b'This is test for proof of work simulation.115'
# Hash Data : 182788711f138b304392a066e7c3e45f78feffbf059624426a42015ab9b1e95c
# Data and Nonce Value:  b'This is test for proof of work simulation.116'
# Hash Data : 99688ef473929c448946eddcc18e983920d7af4777edd484e3cf30592781d55c
# Data and Nonce Value:  b'This is test for proof of work simulation.117'
# Hash Data : e681d9af48a784bc874e05178c6417fd727e532309a21af0ad1aca55b74ce4e7
# Data and Nonce Value:  b'This is test for proof of work simulation.118'
# Hash Data : d89031cbdf28fcf92ac53aa30cf0cdc15edcf77041b417a7b46cc2890e2c791f
# Data and Nonce Value:  b'This is test for proof of work simulation.119'
# Hash Data : 0ac191afb520dcf3072e30cc369deb006e483e52ec35a7dca97b32c28c59e9d4
# Data and Nonce Value:  b'This is test for proof of work simulation.120'
# Hash Data : 963735528c4b8c4b8cbc7eea4bc2e4f89e845ab69dd2c7ea1652080e5ee73aec
# Data and Nonce Value:  b'This is test for proof of work simulation.121'
# Hash Data : 3c3a8cd7775f203da04f1d54bdb34d35c7f14998deaf616da8afcaee5775e3e2
# Data and Nonce Value:  b'This is test for proof of work simulation.122'
# Hash Data : e414b5a79115aeb7988195e3166ebcbbea10a4438e8ea7837de386b9279c907b
# Data and Nonce Value:  b'This is test for proof of work simulation.123'
# Hash Data : 26dbf4c8a6bdb1d716cfc46a48cdc1e6b6f9b6956dbaf83da9efc1b2781264ad
# Data and Nonce Value:  b'This is test for proof of work simulation.124'
# Hash Data : 9903a8518e38af7d35cd8fb1f09cb1bc262648d1718966077cb8e376510d4960
# Data and Nonce Value:  b'This is test for proof of work simulation.125'
# Hash Data : 8286b06d1c24bf79b616afc0d5c97c5fe1015a041fe36fc3a9ad0da0c1aa1608
# Data and Nonce Value:  b'This is test for proof of work simulation.126'
# Hash Data : 581a6e2f87db385a325b265a80bcf3a1723490b3709ecee6112a82425f2ed786
# Data and Nonce Value:  b'This is test for proof of work simulation.127'
# Hash Data : b916284d776d8fbfde78f41fe2a6d09faa6d253a3e46f363650c55d15b9f0334
# Data and Nonce Value:  b'This is test for proof of work simulation.128'
# Hash Data : b15292f6b8469a8cd3e6fac7598346ad8ee0d12eb4f1c6934cb93656b68bc0a0
# Data and Nonce Value:  b'This is test for proof of work simulation.129'
# Hash Data : 529017bc01c3b62c200028c8f4f95d8e7147d21e7be4f37f265cc99b0f749174
# Data and Nonce Value:  b'This is test for proof of work simulation.130'
# Hash Data : 5c66efb65041f764d390b3ef6d72ad6f00e7c5fcdcd6b0fa0ac22f65066e359d
# Data and Nonce Value:  b'This is test for proof of work simulation.131'
# Hash Data : d9031d46c2373bb8a4b52c68ec56357732f1e9520d32f91124a6e27a94efcd2b
# Data and Nonce Value:  b'This is test for proof of work simulation.132'
# Hash Data : 88345cd482a549a9806181313eb3dcd99abeb0d616d45f0792e0c10c4041ebcd
# Data and Nonce Value:  b'This is test for proof of work simulation.133'
# Hash Data : 15e303f3f668d3a7bf1a5c0b26e9344151fcc6d15f0219fba4d7fcf48a77e054
# Data and Nonce Value:  b'This is test for proof of work simulation.134'
# Hash Data : cc25507778989ea29319c7d446b6ceeae54e736fd942735ab8d6f0b23301376c
# Data and Nonce Value:  b'This is test for proof of work simulation.135'
# Hash Data : cbb1cc0b604e02b6f8631b1b74694f20540f1d0ab0f33a6721852efd48657eca
# Data and Nonce Value:  b'This is test for proof of work simulation.136'
# Hash Data : 2ab163cb9abeaf5907528210683530f28fc4ca46ec8e703f3fc2e4d2cf8f71e3
# Data and Nonce Value:  b'This is test for proof of work simulation.137'
# Hash Data : 5d01427c4eaec972df2be36aac5beb3551c5d723b905774999c62fcdee2eecff
# Data and Nonce Value:  b'This is test for proof of work simulation.138'
# Hash Data : 5c03a6c627f5a49056a030826e099a8d45b3d33a849b4427659c6ecb1e36ebdc
# Data and Nonce Value:  b'This is test for proof of work simulation.139'
# Hash Data : ae24548a70e4b6932181c140085a497d348a1cf6b0de09be66f05a3b705bc701
# Data and Nonce Value:  b'This is test for proof of work simulation.140'
# Hash Data : 70e8115dc840acb2a5267c7d2df5562ca15ef75bbaa3b9b15c775e00a8959280
# Data and Nonce Value:  b'This is test for proof of work simulation.141'
# Hash Data : 843f9a0702459c856766ea04f707d72130987e6eb93060343348f595cba108c7
# Data and Nonce Value:  b'This is test for proof of work simulation.142'
# Hash Data : 233866dea6fea7cda3250fd40fe15281d9846669d189f0305aa7c49855263692
# Data and Nonce Value:  b'This is test for proof of work simulation.143'
# Hash Data : 3556a60a599222e0938cb9585d7549798321cc0f66959a044c30b86ad7812a8c
# Data and Nonce Value:  b'This is test for proof of work simulation.144'
# Hash Data : c74931f0822870ae7745e0e9585e849c5d45443485d4db7cc574b3c2ae4f0941
# Data and Nonce Value:  b'This is test for proof of work simulation.145'
# Hash Data : fcc0aedf1f2ea2d0c951f748a1a82364d85677429c2ab8e87096b5b4e341c50a
# Data and Nonce Value:  b'This is test for proof of work simulation.146'
# Hash Data : ffe618256b4e3ba7d19bc1990b00507cacffe604f659559b45014fe47152ac8e
# Data and Nonce Value:  b'This is test for proof of work simulation.147'
# Hash Data : 77c11a99c43ab3de07c3a39f0a9d77667dc1e75e63251f8f759594aab7142d62
# Data and Nonce Value:  b'This is test for proof of work simulation.148'
# Hash Data : 5ca8033982f6bad48a1cfe84735e2f5b18a1521a5f59797b7e8eea746e0b83d2
# Data and Nonce Value:  b'This is test for proof of work simulation.149'
# Hash Data : c953c9443006f6609ca1331e0750fa61fe8c209e6f3aadba1022c7c7c9b68f98
# Data and Nonce Value:  b'This is test for proof of work simulation.150'
# Hash Data : aefbe8dcb56812c194e7bb598346b1a797a5c10b8ae2c08efd8949c06ced66ee
# Data and Nonce Value:  b'This is test for proof of work simulation.151'
# Hash Data : 30b289c8e6534e05befe17936982108b4da73f78756ca7b89ed447471737c36d
# Data and Nonce Value:  b'This is test for proof of work simulation.152'
# Hash Data : 6dd57cf285d6429c02363a053cd8af3a20abf4052ce78a4227bcbb003c517b4e
# Data and Nonce Value:  b'This is test for proof of work simulation.153'
# Hash Data : 7f5df3cf5f08e5870b9f0569de3984955c18ad2633358810f6ab32e78e6f937b
# Data and Nonce Value:  b'This is test for proof of work simulation.154'
# Hash Data : 9796ccad3a46e22e00a06169d5c14ef593d70327aef18cdfa77cfbfa5a498ab6
# Data and Nonce Value:  b'This is test for proof of work simulation.155'
# Hash Data : 83d4de35d73f87589da59d5c5b9bb56b185abbe0a92cbb238bf3379cb96d1892
# Data and Nonce Value:  b'This is test for proof of work simulation.156'
# Hash Data : 8fdcaae177b5a2aa099622fd92a93faeec79777014839be326b008ae22809d4f
# Data and Nonce Value:  b'This is test for proof of work simulation.157'
# Hash Data : 4e63a4cdbea720488c5939666ff83541ecac52c05538f90e666d76ac274f80f4
# Data and Nonce Value:  b'This is test for proof of work simulation.158'
# Hash Data : 51576793f0088586e1a2599fc4784482a11e95f567e268900fa109e88a0202b3
# Data and Nonce Value:  b'This is test for proof of work simulation.159'
# Hash Data : ced42d42369ef271611e5ee4df9f5e7de13eb1b6c0a4984aab0d10e44ed03285
# Data and Nonce Value:  b'This is test for proof of work simulation.160'
# Hash Data : 12ece238fb3adf38a7c93e13ec44a558077b9d89c6d686c5dbe2cebe9670e5aa
# Data and Nonce Value:  b'This is test for proof of work simulation.161'
# Hash Data : 64e84fcaa0f6b0e67e191eb1e240a653fe3800f59b6b4bcfc997ec2dc42bdae7
# Data and Nonce Value:  b'This is test for proof of work simulation.162'
# Hash Data : b9e01652f7506effa157316f0e9e0fc33870728c94c05df296b6e6a57024bbcc
# Data and Nonce Value:  b'This is test for proof of work simulation.163'
# Hash Data : 6299cc4553eb71042e56f4d5c9c847d75e4c158d433b392256e7588cb61e6fb5
# Data and Nonce Value:  b'This is test for proof of work simulation.164'
# Hash Data : 9a59f22c19e258d27ca06724d938518cac24811588cf6992dc16dcaa023584c1
# Data and Nonce Value:  b'This is test for proof of work simulation.165'
# Hash Data : c65ba5a54fd0d9e42e465572a2cbacdbc9668d3fdd33223c3e824c5e1bbaa42b
# Data and Nonce Value:  b'This is test for proof of work simulation.166'
# Hash Data : 4d0f3d68f81a02915e4b55e6ebbb13d54144e34e86298b75c45f32ef48e3ae6f
# Data and Nonce Value:  b'This is test for proof of work simulation.167'
# Hash Data : 2b515ce771558fa0423d18be995d2f38c3de8bb78ef3a50875dd3ab9d8fbb91b
# Data and Nonce Value:  b'This is test for proof of work simulation.168'
# Hash Data : febda45d7b239e4c97af2e645d9eeb9604bc80672438e63a7120b7233fe152a3
# Data and Nonce Value:  b'This is test for proof of work simulation.169'
# Hash Data : 84598cb465650b3fe85ab437999d47e7c5a1cee8236af361aa80694a6af59775
# Data and Nonce Value:  b'This is test for proof of work simulation.170'
# Hash Data : 96dd3acdeff95a155c564e519474f3898e9b220413ce0148f5d683644e574e52
# Data and Nonce Value:  b'This is test for proof of work simulation.171'
# Hash Data : f11d210793d87488924dea15b3634e8e80392db9b4c2b756da154908117e8f20
# Data and Nonce Value:  b'This is test for proof of work simulation.172'
# Hash Data : 55c58ae10ce851741053abfce80fe434595bb338b923f3a97b44473a4ee0d7d0
# Data and Nonce Value:  b'This is test for proof of work simulation.173'
# Hash Data : d3a46c8b1379b9c642f40d080950423071c1c21a14bcd822b5ad1c49b4447152
# Data and Nonce Value:  b'This is test for proof of work simulation.174'
# Hash Data : 7e25426020ffea9553f210e897d7ab2a3006d727dad5e4c96cca529466dd742b
# Data and Nonce Value:  b'This is test for proof of work simulation.175'
# Hash Data : 35bd814009cd7a7505ebd727d4025d35255077002d9e1cd142a55950dcb426b0
# Data and Nonce Value:  b'This is test for proof of work simulation.176'
# Hash Data : 8e2eaa15fc67ce8680cbd031cb88a1a9fc678ec685af9719fc45d329b79655f1
# Data and Nonce Value:  b'This is test for proof of work simulation.177'
# Hash Data : 0f685dfa69f7dd0bb9aeec3b6dde66d522a704b3bf23911f58803f879be9c847
# Data and Nonce Value:  b'This is test for proof of work simulation.178'
# Hash Data : 363b72f26c1159c3d607455b0218ffc8f6015e3b9af7f62b6ad9b4cdfd1aac7f
# Data and Nonce Value:  b'This is test for proof of work simulation.179'
# Hash Data : d80ec3450442b380470ec746edc7a0251467bb412d45275510000bd27dbd8ee4
# Data and Nonce Value:  b'This is test for proof of work simulation.180'
# Hash Data : 0ce01f07097c76eb291a094095a06053bacb669396c2eedaf9a21f2bfa963f43
# Data and Nonce Value:  b'This is test for proof of work simulation.181'
# Hash Data : 3c33b8b36b136ba3af78c07623812b5394aed0aa224156af021751e0c88029e3
# Data and Nonce Value:  b'This is test for proof of work simulation.182'
# Hash Data : 669bb4be7ceaa43eaef1b05e59cebedd1e50d0a41ca9b304c6f2952bc6b2c667
# Data and Nonce Value:  b'This is test for proof of work simulation.183'
# Hash Data : dace323b2cc173e211b748ebe382315c5d1a0ed5d2897b93fb1efdfbf963d857
# Data and Nonce Value:  b'This is test for proof of work simulation.184'
# Hash Data : 28693c0bde024218afb90f8b24852264083ec75bd3f1691ef2bb5ef9c7c8371c
# Data and Nonce Value:  b'This is test for proof of work simulation.185'
# Hash Data : 6875ea68e12d6d467276f2c5b2a902c09a6913bfed02632a4dcce8ad529680a4
# Data and Nonce Value:  b'This is test for proof of work simulation.186'
# Hash Data : 67fc3639442cd2deeb8fe5efbb4881d3d4286d4578145cea4d0692e7d215bf25
# Data and Nonce Value:  b'This is test for proof of work simulation.187'
# Hash Data : eb89066ab1714ac15543c64385bdb0fcbb65022f83a3d5f9705b0eca6aff74d0
# Data and Nonce Value:  b'This is test for proof of work simulation.188'
# Hash Data : 624584be1095d12bb78f66ccdee7d032d3c514ef1f68f43f379b39fbe5bcc6de
# Data and Nonce Value:  b'This is test for proof of work simulation.189'
# Hash Data : 2e99954145eb98d4538d012f4fc5135069f300254c1887138d6db4113e0e9158
# Data and Nonce Value:  b'This is test for proof of work simulation.190'
# Hash Data : dea818cd189ff423b38791cc7aeef69fe07d1daee299691f1afeb42065f6bb87
# Data and Nonce Value:  b'This is test for proof of work simulation.191'
# Hash Data : 0f480e61539b6eff8924744bf50404a497b4d11242f5154ae047c1eebd4f496b
# Data and Nonce Value:  b'This is test for proof of work simulation.192'
# Hash Data : 7b44c3c9ed73b150a10cc892fa911daf69b3d7f1b3d1b4963f8976a1e085d039
# Data and Nonce Value:  b'This is test for proof of work simulation.193'
# Hash Data : 54ab30107337f43a04fc6335d6fb7bcdf98e448e2bc757f4ebcc6de7eaa2638a
# Data and Nonce Value:  b'This is test for proof of work simulation.194'
# Hash Data : eed35b086dfb435e89b14c76b61707f2054e7394d412fd819579ec14fa069470
# Data and Nonce Value:  b'This is test for proof of work simulation.195'
# Hash Data : 9fc2fdc323eb3f21d872f49c4729096c3e9b0b87d25a967f27a7ea805637427c
# Data and Nonce Value:  b'This is test for proof of work simulation.196'
# Hash Data : 9e34310a6d89456b609edafa66c0ba1bb3a00607eb4e9155c5a84e8861e62223
# Data and Nonce Value:  b'This is test for proof of work simulation.197'
# Hash Data : 5baec93a3f57083c5654b741beaf33815ed85e49a95c457e27abf723523e3aa3
# Data and Nonce Value:  b'This is test for proof of work simulation.198'
# Hash Data : 35c256d5bc4749b4a7ef7f66d172260e043429648d587a3b4b56206196c43d35
# Data and Nonce Value:  b'This is test for proof of work simulation.199'
# Hash Data : dba69fc4d3bad4b6866e87b3ac58472a85c30a7e703dc4b57a448ae4005de479
# Data and Nonce Value:  b'This is test for proof of work simulation.200'
# Hash Data : ee53dab814aaec1baf5853f938f727ea08c45f63673350d294d9e667236c596b
# Data and Nonce Value:  b'This is test for proof of work simulation.201'
# Hash Data : 871c8a99517fe00ad9ea0bd90cc59fb04b29ab10e2c62f1a7c961d90b3c431b4
# Data and Nonce Value:  b'This is test for proof of work simulation.202'
# Hash Data : 37eed79774394128001f19383ab8e4b429df05be380b87cc80b757b328e10a73
# Data and Nonce Value:  b'This is test for proof of work simulation.203'
# Hash Data : fdd8ec5a51838905f5992d18bfe807364991fef6e603579f6f00d0a673da6590
# Data and Nonce Value:  b'This is test for proof of work simulation.204'
# Hash Data : de2cbeb8d64335c1a087302cfc084da807d568ca86d28178ecb68eb758141b7f
# Data and Nonce Value:  b'This is test for proof of work simulation.205'
# Hash Data : 5a738f64d40173d4b9db9b30f5d9f5122d636926f77b2a588e0314b7e6bd3d3f
# Data and Nonce Value:  b'This is test for proof of work simulation.206'
# Hash Data : bf52f4b0a7761f3806723f6dcfb13d30e6a2863f5c7b4f972ece8e28b855f1df
# Data and Nonce Value:  b'This is test for proof of work simulation.207'
# Hash Data : 30f6eb87d023da72a2cec0d96fb9807b597e77e1d97e1f5098f2018f3606ef5c
# Data and Nonce Value:  b'This is test for proof of work simulation.208'
# Hash Data : ef95dd93796413f8d75637979e0e579a4f8b62fc945b1826b228db964e9d99e9
# Data and Nonce Value:  b'This is test for proof of work simulation.209'
# Hash Data : 36d10ac0853ccb1a14d13074227f0bf7969c332b94155da10310f31ae0cec9db
# Data and Nonce Value:  b'This is test for proof of work simulation.210'
# Hash Data : d1c0a782b0f9e5b882ea48e529944318e1801d2203bba1c1ad81355c7d6a4e30
# Data and Nonce Value:  b'This is test for proof of work simulation.211'
# Hash Data : 1d5faa246672c6216ede04e9580dd7f8ecc9c88b12914e1b510db4d4abe6b0a8
# Data and Nonce Value:  b'This is test for proof of work simulation.212'
# Hash Data : 8695ff87d34483b35fcbe28766118f791e273cc7646e27cecbddda475ee2948e
# Data and Nonce Value:  b'This is test for proof of work simulation.213'
# Hash Data : c862fc051a8c0d343f6be5563d322f1361c8be47ff1cdacc7b6af9e9753caa76
# Data and Nonce Value:  b'This is test for proof of work simulation.214'
# Hash Data : f65dacc634d635094befb3bfe9b00b037e72b69d89f020547d8e97950c5080c0
# Data and Nonce Value:  b'This is test for proof of work simulation.215'
# Hash Data : fba295b630c7cac254800b15dedaaa5dc43a339c11c0859682c4596466d74eb8
# Data and Nonce Value:  b'This is test for proof of work simulation.216'
# Hash Data : ab9c99360021db79a336a49238e866a6fc20d0bb452140485f8ec30a8e5810a3
# Data and Nonce Value:  b'This is test for proof of work simulation.217'
# Hash Data : b72ccf43d8a582c1fed7222308ea800d56789912dd4c452a283cda18e768b588
# Data and Nonce Value:  b'This is test for proof of work simulation.218'
# Hash Data : 786514426a33f3a65d036513a1c8db43ac1d44fa06e7c936332533858584b693
# Data and Nonce Value:  b'This is test for proof of work simulation.219'
# Hash Data : b5cc281bcdccb29f777b091054937fb5b47538ad0f93f690d8294ef4293083fa
# Data and Nonce Value:  b'This is test for proof of work simulation.220'
# Hash Data : 7a2521d9b01e55d7a9b56355ac26f27ee64f6096fc1d8be12e173dbb43f08402
# Data and Nonce Value:  b'This is test for proof of work simulation.221'
# Hash Data : b962d4187e5ab28460b336e1716a278dcce70e5d2f17e378bb2e9fd02558b51c
# Data and Nonce Value:  b'This is test for proof of work simulation.222'
# Hash Data : a00c5b96fcaf18aed4770046a915644b517ef58cb1c2ce92afbf1e07b5b2318d
# Data and Nonce Value:  b'This is test for proof of work simulation.223'
# Hash Data : 7bc51734bad39932d05bd30f0b2e3cff720371ce4f202879cd506113098307c3
# Data and Nonce Value:  b'This is test for proof of work simulation.224'
# Hash Data : e24561ec1d21ae43b93c5b6acd975b905582d0e471f0039f84546d3f231b29ba
# Data and Nonce Value:  b'This is test for proof of work simulation.225'
# Hash Data : 85872641701e8375ef37bc8f42178f14b8da8aa0bf92ec85a63962c436d43e9b
# Data and Nonce Value:  b'This is test for proof of work simulation.226'
# Hash Data : 5fd33bec90b0eca2e5ad16d0866a9df43ced67844f55e7d4ba90383788fab843
# Data and Nonce Value:  b'This is test for proof of work simulation.227'
# Hash Data : e18d69c8ed5900f9ac025ca380c06aeee43cac8b95c685e5dc38dc1d47a5110c
# Data and Nonce Value:  b'This is test for proof of work simulation.228'
# Hash Data : b27773e5660aba66369a33743344136577635e79e2d108a7538ca91e93b3c28d
# Data and Nonce Value:  b'This is test for proof of work simulation.229'
# Hash Data : 18e5faa16d417cfe6b049d3b858d712d7aa0ad7ec7ecbd87feab72bd4f5cb43c
# Data and Nonce Value:  b'This is test for proof of work simulation.230'
# Hash Data : 21335aa05d9b242316c3727033cf3122b2de8c2ba3e80c5ed09575589be7df2a
# Data and Nonce Value:  b'This is test for proof of work simulation.231'
# Hash Data : b9d4665bddec684436bc046e06ad716ed20474870075152aabae2a18f825924d
# Data and Nonce Value:  b'This is test for proof of work simulation.232'
# Hash Data : a3a45715a733c60087908021f3a4a9d3a3105633e715149d8403bb438ba39d3f
# Data and Nonce Value:  b'This is test for proof of work simulation.233'
# Hash Data : e7d3352fca83f321a797e18290b26020dac9255101dd60a1529e709f97fa2c7c
# Data and Nonce Value:  b'This is test for proof of work simulation.234'
# Hash Data : 535a496c474c409e1e86d2cd7eb3aa4a786129f680e7dd8384eab2ce9ccf0866
# Data and Nonce Value:  b'This is test for proof of work simulation.235'
# Hash Data : db9d7700a5a842996cb5fb563d7d18dd50f8af5540efa4e22a03538bf99e4142
# Data and Nonce Value:  b'This is test for proof of work simulation.236'
# Hash Data : 596a6c51a7bfb2f6d483a129f91250336215c4ad997639f3a5ccdedfcbcbcc38
# Data and Nonce Value:  b'This is test for proof of work simulation.237'
# Hash Data : 13348f19a8eaedd0079ed44aa492c2e5d8bfb1234ae02a74184adf208314fcbd
# Data and Nonce Value:  b'This is test for proof of work simulation.238'
# Hash Data : f48892bbf87f2736676cdf9bdca8ec0cf25126ae67b81d94e7228f1eccb9bbac
# Data and Nonce Value:  b'This is test for proof of work simulation.239'
# Hash Data : 68331c05b61da8599b9dbd4d588a34eaa86ac86dddff26553f0d9557d6211f65
# Data and Nonce Value:  b'This is test for proof of work simulation.240'
# Hash Data : a198eccd562090d70776136f8e07baf930e6e8a264f693ec4cfe1a77106c8546
# Data and Nonce Value:  b'This is test for proof of work simulation.241'
# Hash Data : 6e6aba324af056a763d277b020d66ba9770d94a3fd78c45503c46b5aa7e8d468
# Data and Nonce Value:  b'This is test for proof of work simulation.242'
# Hash Data : df9bb954fe7804f74c48d44fad15c101147e688b35243fdc82b224eea8656fe4
# Data and Nonce Value:  b'This is test for proof of work simulation.243'
# Hash Data : 5610d062b99db94ff5e7d4a7a80241d7a43463c73a0628e2ee9f74866b435979
# Data and Nonce Value:  b'This is test for proof of work simulation.244'
# Hash Data : dc81b75ec0fdfc91c3852620e449cd122b80a85e670aed4a5ffe37ff49a339f0
# Data and Nonce Value:  b'This is test for proof of work simulation.245'
# Hash Data : 2e97fec6c3644b0c26544a99227005ac32af58fadfbdc9547e54c45d12e6c8b5
# Data and Nonce Value:  b'This is test for proof of work simulation.246'
# Hash Data : 66c28672cae26d14d8daed4f199255f3838027c1ab51935eda55dc0a35b308d4
# Data and Nonce Value:  b'This is test for proof of work simulation.247'
# Hash Data : 126020bd7d008ebd6298ea71e21b377c04b73b47c7829dc05ab529682893934b
# Data and Nonce Value:  b'This is test for proof of work simulation.248'
# Hash Data : 4358a296417a096530f47a87389518bcb8f6e7ce4fdaea88dbfaed850a41d1e7
# Data and Nonce Value:  b'This is test for proof of work simulation.249'
# Hash Data : 2a31eefd8187a414a802ce53943cdc98f4b2cd2cf6dd19d2bfcd9faeeb4aeb0a
# Data and Nonce Value:  b'This is test for proof of work simulation.250'
# Hash Data : 86e4ac1125b8e541531552a3403e5c370cb5a380eae6a999fe93b66d8f53f3ce
# Data and Nonce Value:  b'This is test for proof of work simulation.251'
# Hash Data : b639d00cae1f17990a66cd7ac2d49f2f24df44cd67c17fec7c8db7b3a6baf053
# Data and Nonce Value:  b'This is test for proof of work simulation.252'
# Hash Data : 64cb5870a74af4b0790d3442764f441a3372fd789c8d4756b410c5846744d240
# Data and Nonce Value:  b'This is test for proof of work simulation.253'
# Hash Data : 9e363c7a9c801c97af67b186296529c2559300550ddad76ef3b4684821a80ba6
# Data and Nonce Value:  b'This is test for proof of work simulation.254'
# Hash Data : 62260999e79148a32b21f0fb8b4a6460802410887799f5da66226aaf43d44ff2
# Data and Nonce Value:  b'This is test for proof of work simulation.255'
# Hash Data : 8ae27aa25f16eb5ef1571b52aef07d1c92d29ee458ac038af223610ba7eeb637
# Data and Nonce Value:  b'This is test for proof of work simulation.256'
# Hash Data : f8b5304135f44c7dd5261b86f8e90e636a371b2ee2f88bbbb7faeace166347bf
# Data and Nonce Value:  b'This is test for proof of work simulation.257'
# Hash Data : 264ed93455e7bd8fd83ba8750fc11d96198044b05ec49b698380be8dc0a0813d
# Data and Nonce Value:  b'This is test for proof of work simulation.258'
# Hash Data : 1af1a4bd64c01dd9fa24e9d860575e3728b656924351f1f5e927c303102f5361
# Data and Nonce Value:  b'This is test for proof of work simulation.259'
# Hash Data : 325f1180a1e798faa58f99bb9eb7479083640ec22ecb97ba8f9165128bc6d87a
# Data and Nonce Value:  b'This is test for proof of work simulation.260'
# Hash Data : 3b49f7da6d815696f9ad38fa60fcf999eabfb2af770df78b4cef812926985fa3
# Data and Nonce Value:  b'This is test for proof of work simulation.261'
# Hash Data : d6cb9f4afb7370e57665c0792b50b0da8b7eb4484f5558db1cc15cd86f45ac84
# Data and Nonce Value:  b'This is test for proof of work simulation.262'
# Hash Data : 970ea20fc6e8f4da07333da2f3e6c5ec70c87ad2bacacd83ec40ea520ad04395
# Data and Nonce Value:  b'This is test for proof of work simulation.263'
# Hash Data : d7449955c078cf509c4c926736d305a57c65e23f254d6d48ceba2fe9eb0c6033
# Data and Nonce Value:  b'This is test for proof of work simulation.264'
# Hash Data : b49891b631abf2884ea25827ada386b84f2a8bae2268e6eaad02c9e327ca3412
# Data and Nonce Value:  b'This is test for proof of work simulation.265'
# Hash Data : 6eb8972037d9f2468f6611af38bffc375ee7455ae0cd86f9627405f17387982a
# Data and Nonce Value:  b'This is test for proof of work simulation.266'
# Hash Data : 884d1ca95cbfa74b48d084bbd26578b6c11c93decac61522554b53fcad9fddc1
# Data and Nonce Value:  b'This is test for proof of work simulation.267'
# Hash Data : 1b6995aabd14c072cd0ee285fef6f440b2611f2892f1d237fcf36fc4ecbb84dd
# Data and Nonce Value:  b'This is test for proof of work simulation.268'
# Hash Data : a6d2a5c560481cf85b709c6818ca5db268926f3cf998756c3cde87978182f8ee
# Data and Nonce Value:  b'This is test for proof of work simulation.269'
# Hash Data : e18b7ad80816083deb57374c5b1c209d8d6ff28c01f4f193c01e5b223387bc71
# Data and Nonce Value:  b'This is test for proof of work simulation.270'
# Hash Data : 8bc63db4d909470c54ac5914dc5131575bbde50fe4d6035388195d9c6a0a1292
# Data and Nonce Value:  b'This is test for proof of work simulation.271'
# Hash Data : c2f415f16c94aa83da27fc8725654566d0ae4a98ae6686c6aeb6ac095e01a5c4
# Data and Nonce Value:  b'This is test for proof of work simulation.272'
# Hash Data : fc1712e5d1ca030959cf22bb38e4490062cf0d47009bbf2da7f9f9ac2ce85555
# Data and Nonce Value:  b'This is test for proof of work simulation.273'
# Hash Data : 9381d2369b96a7c1e8cc10aa9d65668dcbec4440211a6def8cfc277754054422
# Data and Nonce Value:  b'This is test for proof of work simulation.274'
# Hash Data : 20e896198388d5e15a2edeb119f1e1a8b0aa4dc120097ad98d4058dcd56e0e01
# Data and Nonce Value:  b'This is test for proof of work simulation.275'
# Hash Data : e568d483e1162e862b87a105a8e04fee5ce6f7a13ca4309b0845bdf7d94b3189
# Data and Nonce Value:  b'This is test for proof of work simulation.276'
# Hash Data : 3ed4a7a6902cd318ac938572be0a32ad3e55c28b8f13de6f4addd5aa3976cb93
# Data and Nonce Value:  b'This is test for proof of work simulation.277'
# Hash Data : e46d2b721126498311b1f26a7973eb93b361d3fc2421f7a53788b36dd41ae2c6
# Data and Nonce Value:  b'This is test for proof of work simulation.278'
# Hash Data : 8a7666d6c2d15b2749d13f5a3221a847307456debfd4b1b6cb95f1be6ade06c3
# Data and Nonce Value:  b'This is test for proof of work simulation.279'
# Hash Data : 456b62f05962e84247cc5c98a6fd860978ca738c642d811b686d4699866ecc77
# Data and Nonce Value:  b'This is test for proof of work simulation.280'
# Hash Data : 2841fabb53b42aab2974ecd6e1e1adde588d74095ab6a5dff73c3d0520d9756e
# Data and Nonce Value:  b'This is test for proof of work simulation.281'
# Hash Data : ef40d95011b75c4f1e2090fa23f80b70996d0084de77ac31723d1fd9481d7c7c
# Data and Nonce Value:  b'This is test for proof of work simulation.282'
# Hash Data : 7c14dcb3424eb5315a06363cb55f0eed200e3e94945e63679c5ffac3daff7664
# Data and Nonce Value:  b'This is test for proof of work simulation.283'
# Hash Data : 911e25c69c0a411f3ce0b0d5f7371dc562b5491abde1ddbc5e41f98a6d05a87d
# Data and Nonce Value:  b'This is test for proof of work simulation.284'
# Hash Data : 811c4489d7592cb47c6f9f222927fbbb405253b0611b8be166f7e83769d94c18
# Data and Nonce Value:  b'This is test for proof of work simulation.285'
# Hash Data : 528a055bc45be4748e173ba119506173111be494ddbc9507dd41c9e983c68e00
# Data and Nonce Value:  b'This is test for proof of work simulation.286'
# Hash Data : 1d049c023437b5915cefa577523e2c08e5a248651fb1774eca89e5791434a308
# Data and Nonce Value:  b'This is test for proof of work simulation.287'
# Hash Data : 2f3774c1e0385f471c260e097562c067d036ea9bd00cb5a23df0abe3c95992c6
# Data and Nonce Value:  b'This is test for proof of work simulation.288'
# Hash Data : 8b9c5ebbc4fe08ad7b0ecf8ae1a3190ab75f45a3bd60838ab44e57adc030b210
# Data and Nonce Value:  b'This is test for proof of work simulation.289'
# Hash Data : 903f586bd07540532c24c1b90a74e60792a2fb3ca597963a18c4dc62b33589b0
# Data and Nonce Value:  b'This is test for proof of work simulation.290'
# Hash Data : 2bf50610834f0b7fd454c5f7d8e50d5a2e42998f65cf7383415e7fbee0637311
# Data and Nonce Value:  b'This is test for proof of work simulation.291'
# Hash Data : 6f569adada3d93defff0b18985e6ca307aab020df6d74438dcf1327fe9c87112
# Data and Nonce Value:  b'This is test for proof of work simulation.292'
# Hash Data : ee4dad0e2b41e2d26088fd11ee26f6459d661f7532acfda0db93015ab90ba701
# Data and Nonce Value:  b'This is test for proof of work simulation.293'
# Hash Data : 90e9955714717dd8d57136166e39f01a529c8961dc858de546a3348fa0de6e4b
# Data and Nonce Value:  b'This is test for proof of work simulation.294'
# Hash Data : d4fe6310091863f8bdf3921f51182ba4dbc86f03c193639db7cfee6567c35c7c
# Data and Nonce Value:  b'This is test for proof of work simulation.295'
# Hash Data : 22d299367fe7e23c3cc90b27733376e07c2a153685e0436c6b5d4e6c303e7a70
# Data and Nonce Value:  b'This is test for proof of work simulation.296'
# Hash Data : 2f746e77780303c506e5ffdbdb844e4e1f3017c0f9dd2428e86ce18a03037be2
# Data and Nonce Value:  b'This is test for proof of work simulation.297'
# Hash Data : 8f384767372781a731cfed9f679fb77f2f011d60764b0ca4c7c30d679189896d
# Data and Nonce Value:  b'This is test for proof of work simulation.298'
# Hash Data : 9e793bb10600efaf8b14508b876787ba071902cb4e16084644be1e549d7d2ad4
# Data and Nonce Value:  b'This is test for proof of work simulation.299'
# Hash Data : 154250b63347957336781fc35946973c5c9834640a29650d26b754cc9df5814b
# Data and Nonce Value:  b'This is test for proof of work simulation.300'
# Hash Data : bff35f3eec00ad7d5304a3130049ab2003a47aa2ec87c56af822c06dfe1d1257
# Data and Nonce Value:  b'This is test for proof of work simulation.301'
# Hash Data : 1f3a026532e1dcdb56709b9cb7ceba12bfc1e4cd2c9c5a5167f525edd2c87d91
# Data and Nonce Value:  b'This is test for proof of work simulation.302'
# Hash Data : 12b130f857c79b67e5ff3e9dcbcce90145d85d5de0e6fdf1aa0b1ae2c8f0f0b4
# Data and Nonce Value:  b'This is test for proof of work simulation.303'
# Hash Data : 4351d8ea1a517567e5dfe08e6c5f18f3d774612bfe16f349a2c2f2eef7a051fc
# Data and Nonce Value:  b'This is test for proof of work simulation.304'
# Hash Data : 1e0123170f72b7f6ac2a62f0e5525996e0c91172f9f523e05a90dcf5750ff39d
# Data and Nonce Value:  b'This is test for proof of work simulation.305'
# Hash Data : 22fe8f8b2a821f834e00bb1c9fdd5d5c78d7e71857bddb4aceb9e6ef6ebbb440
# Data and Nonce Value:  b'This is test for proof of work simulation.306'
# Hash Data : ebe7c6f15c2ca1369a372d3b9c0cc73ac8bb1e0d407324ff18d76d021c87faa1
# Data and Nonce Value:  b'This is test for proof of work simulation.307'
# Hash Data : 778341eea2c8c612fe665372c8dbdf4c6dd5e3e75158979d000134ac1258c76f
# Data and Nonce Value:  b'This is test for proof of work simulation.308'
# Hash Data : e3e7c3d839e7b5caba6ee209afdc23a39495bbec6331d512a3351d26c5858c57
# Data and Nonce Value:  b'This is test for proof of work simulation.309'
# Hash Data : 80f82957a07c3f07535ee0295fce6e7ee40224b1873d4eecbc24675f5d65208f
# Data and Nonce Value:  b'This is test for proof of work simulation.310'
# Hash Data : fcf47831eab07f3fe7aade9e4a29aaa82ce16507771c54ed3bf1041631df814d
# Data and Nonce Value:  b'This is test for proof of work simulation.311'
# Hash Data : ef31580a4fb843c752a1f87a51d1add6b8b3fb79f78cb7f21d37a7aae41ffe69
# Data and Nonce Value:  b'This is test for proof of work simulation.312'
# Hash Data : 17a0a639ff4b8f07494e22c3a4e718ec368f73e049ff0c113b2c9977d9bc2e07
# Data and Nonce Value:  b'This is test for proof of work simulation.313'
# Hash Data : 32cf728075b74e87db44a381bee5ea69cc8caf99bef65461b3a9f914b1452783
# Data and Nonce Value:  b'This is test for proof of work simulation.314'
# Hash Data : b87e04d96485654bb98dc81f3e7ddb59df41ef9e45171e04b5595b046885fc8b
# Data and Nonce Value:  b'This is test for proof of work simulation.315'
# Hash Data : a71ded3f90c84de5196e3412ed3463509f4c80926beac0935d97fbb65f9b6880
# Data and Nonce Value:  b'This is test for proof of work simulation.316'
# Hash Data : 8bbccd49ed65ec4d42a8aa4d59fd7c994f0865ecc4d9d9cfae8dfcf258848cff
# Data and Nonce Value:  b'This is test for proof of work simulation.317'
# Hash Data : be35f7b0f40efe89608c253a0e947e4eeba187ea229e3297b40f2997e9e90468
# Data and Nonce Value:  b'This is test for proof of work simulation.318'
# Hash Data : 7c85e0c4a98d9182a13b4f75b93d9d9ea5180a138329f030876f49a20e1d05b2
# Data and Nonce Value:  b'This is test for proof of work simulation.319'
# Hash Data : 7b117214d9397458218b6b604bdc0f48464672e335a1b003750d216593edf481
# Data and Nonce Value:  b'This is test for proof of work simulation.320'
# Hash Data : 524205a369894be663db4360fb25beee99a51536d8809c8850fce04dcb6c3489
# Data and Nonce Value:  b'This is test for proof of work simulation.321'
# Hash Data : ed32d8ce16877a1e2e4669f0a199c4bc41acccb49c176256755a3e5d46b1a704
# Data and Nonce Value:  b'This is test for proof of work simulation.322'
# ...
# Data and Nonce Value:  b'This is test for proof of work simulation.12518'
# Hash Data : fab91bdcd1964b0c6f9ed472ba2634a923c872044aa820f41f8367d28134eab9
# Data and Nonce Value:  b'This is test for proof of work simulation.12519'
# Hash Data : 1c8f88212e570761bb30d9b3bde644d8bc8a3436bf637fe4e58ab4d1624c042e
# Data and Nonce Value:  b'This is test for proof of work simulation.12520'
# Hash Data : 21a5f9aeebf98ad46e2ec502f05736c3a123e147a6aa36df5c5dde57c3f2a343
# Data and Nonce Value:  b'This is test for proof of work simulation.12521'
# Hash Data : 7f896d98952aec0493bfdc85c48bff4dbfdbf5a384cec25017b34af9f74e9639
# Data and Nonce Value:  b'This is test for proof of work simulation.12522'
# Hash Data : 3075cfe3a03b92ddcd2c580185ef9724c0754f7f933327f3d531a5963f8030ff
# Data and Nonce Value:  b'This is test for proof of work simulation.12523'
# Hash Data : e31b9f8542cf53e8f3c23c428121f58d33f4c77bf061fbdfce2df6d25c5833fe
# Data and Nonce Value:  b'This is test for proof of work simulation.12524'
# Hash Data : 4772cc449ad1590a687027e01bd9fa51d633f89d1e6ba22495bc986e86cf20e6
# Data and Nonce Value:  b'This is test for proof of work simulation.12525'
# Hash Data : e0c6035d377b7584b8e4ac376cc2bbb33b2be07bc6ccb785d23c2960e91e4656
# Data and Nonce Value:  b'This is test for proof of work simulation.12526'
# Hash Data : cfd1cc2b9b22d8aab8a338bfc88dfceb2cb5bc8d0ebc6b852c96513f674eb8f5
# Data and Nonce Value:  b'This is test for proof of work simulation.12527'
# Hash Data : 3090d1ff5a284299555d664400f3817134a5bb018e9aba90f3a941be818f0d5f
# Data and Nonce Value:  b'This is test for proof of work simulation.12528'
# Hash Data : f768427ce086cf6c5400c171fc61a51176a0e5b9ca3f37c3a1180ee25db7c8b3
# Data and Nonce Value:  b'This is test for proof of work simulation.12529'
# Hash Data : 094efc40d060754eda66a926448f2f501eadfe311a0b613dacae54fc1086a4e3
# Data and Nonce Value:  b'This is test for proof of work simulation.12530'
# Hash Data : 90e3674134e493bc222237a2f569f98421e3e59eb8fd49821b9dd5882de95464
# Data and Nonce Value:  b'This is test for proof of work simulation.12531'
# Hash Data : 7c99bd25710d2b3596597e54ae151ba1df9638e5e8f62091fddcda0da777354c
# Data and Nonce Value:  b'This is test for proof of work simulation.12532'
# Hash Data : 19f85ebcf29d97247ad441b88dbbf8b4d16b4d6e69347b13be2bfabbfe0bee76
# Data and Nonce Value:  b'This is test for proof of work simulation.12533'
# Hash Data : 958464115efc0a93ace4aa274030dc9c4ccde37486341fcdca3f8bb0c473eb54
# Data and Nonce Value:  b'This is test for proof of work simulation.12534'
# Hash Data : 00117514d48796b2592fba87e43d50a7bbe678ba481212c142a9fcb3c23d2c7c
# Data and Nonce Value:  b'This is test for proof of work simulation.12535'
# Hash Data : cb1dc3497a77e4409ce03ffb2332aab1b4605f633d3b46e899641d05efed9fb3
# Data and Nonce Value:  b'This is test for proof of work simulation.12536'
# Hash Data : 20c1bd84c1a9863d80f69c2ac40824ffa7db51a18aac755e9e5d7fa1c47b8ba4
# Data and Nonce Value:  b'This is test for proof of work simulation.12537'
# Hash Data : 6ca14abb6350735647c65c4c3c90a2319e8d13504cb034fd91cec24c379d2ffd
# Data and Nonce Value:  b'This is test for proof of work simulation.12538'
# Hash Data : 7b1d3d81ebfe0f0544558bf66adb0949e73391b73899afa2f21dd5a86c2a4eae
# Data and Nonce Value:  b'This is test for proof of work simulation.12539'
# Hash Data : 11debaf289f3b0045bcb546927c362a1a16fa32bb4adf2c07e4f8674a4117f8b
# Data and Nonce Value:  b'This is test for proof of work simulation.12540'
# Hash Data : 87b262171ac3cb952ff3933a340ff68a4ca2be8ade7e492149e2023169be1c31
# Data and Nonce Value:  b'This is test for proof of work simulation.12541'
# Hash Data : f5dd771c0619539c6bb987c040e5d0b9949faf06d9e042bf7d47e49c5f711bc4
# Data and Nonce Value:  b'This is test for proof of work simulation.12542'
# Hash Data : eee926567b5c22dc91d34ff51dfd08afdeabdb2a79e60293fdc98a30d1a04778
# Data and Nonce Value:  b'This is test for proof of work simulation.12543'
# Hash Data : 7a053a4d73d13c782eb20432f5e71078a0e3f07959b12045acaefb6668113c46
# Data and Nonce Value:  b'This is test for proof of work simulation.12544'
# Hash Data : 111e3a15ac7ae7085232c5a667281749196fbf27cd9e7fb49cde4b5df5a9cf33
# Data and Nonce Value:  b'This is test for proof of work simulation.12545'
# Hash Data : f25ecfee2b8633c4846d05c4c1b45a03202ab82f0512e1dd9c81543bff16caf9
# Data and Nonce Value:  b'This is test for proof of work simulation.12546'
# Hash Data : 2be81ba5a698c7163f747f8434093c7fa554df971c26ec1d775752b70eb2efa2
# Data and Nonce Value:  b'This is test for proof of work simulation.12547'
# Hash Data : 70183d74409b60df5ca375fa74d8b71787765899b0de4e9b4ba9ccc346243d8b
# Data and Nonce Value:  b'This is test for proof of work simulation.12548'
# Hash Data : f1fbf8f41bf3e6478dfcd0e896b11bd19627181b7780a11fe45c1d80b27cc997
# Data and Nonce Value:  b'This is test for proof of work simulation.12549'
# Hash Data : b5407cc114f744adb0d1739ae4305fc933939a53d35b278a313519617c5fcef8
# Data and Nonce Value:  b'This is test for proof of work simulation.12550'
# Hash Data : 12a7f47b6bd9d3bb5cacff2a621748bd99a03add9c0fccb2f3a2cdcee8a9dac1
# Data and Nonce Value:  b'This is test for proof of work simulation.12551'
# Hash Data : ef3202ff776970507f9151fbc75480ffb69e517ec73d59de5e17dec3b717e77a
# Data and Nonce Value:  b'This is test for proof of work simulation.12552'
# Hash Data : 154233d10aa703e8525ea3a18ca9fa713c51d8e06e228b2cf8170ac477ef9110
# Data and Nonce Value:  b'This is test for proof of work simulation.12553'
# Hash Data : 38ebcea23f69c7be30fd4efb131689ce9f35844e2627a163bcaf0a1aaaf104a9
# Data and Nonce Value:  b'This is test for proof of work simulation.12554'
# Hash Data : 7e01f885e5d6b5a7a056cc9c052307103d42a01897c4ea79b0cc4f7b26c678dd
# Data and Nonce Value:  b'This is test for proof of work simulation.12555'
# Hash Data : 106dbe357225a8f0676a4476b9e4876b9676f455a20bdb414d59c9d46791aed4
# Data and Nonce Value:  b'This is test for proof of work simulation.12556'
# Hash Data : 1e7374f73ebb268bff97dd5a808b87ae5c976d1472d2c2fbd7bea33a5f61ca2b
# Data and Nonce Value:  b'This is test for proof of work simulation.12557'
# Hash Data : 003192435e2f7bf0809105758f666785b713c67a8c73978458ecd75deee62222
# Data and Nonce Value:  b'This is test for proof of work simulation.12558'
# Hash Data : 20a072369a1131eaa6dcf517a5dabdcf9721c8d5b09ee5f105683e2e47df843e
# Data and Nonce Value:  b'This is test for proof of work simulation.12559'
# Hash Data : 84b8a3e9e50bdd3fd00c94cd1f19801313f57a679831b5c1f59ce5cdb84c1210
# Data and Nonce Value:  b'This is test for proof of work simulation.12560'
# Hash Data : 16a5581ba3a6b7dac2afdbe8ed59c29fa7479de3a7c34be47057939314f57a8b
# Data and Nonce Value:  b'This is test for proof of work simulation.12561'
# Hash Data : 05179eb6cec8c58935141482b9499a8b469cd994a5a88a48b53e5efc44ef8393
# Data and Nonce Value:  b'This is test for proof of work simulation.12562'
# Hash Data : 8ae77cf3a05fd2c0933c2eddde2893abd8205a26a266bf75c0a2cd2269e55607
# Data and Nonce Value:  b'This is test for proof of work simulation.12563'
# Hash Data : 661d13c465eadcaa8d08d20994ac68536f3f6183677bee9ab7905d37dfe45ab0
# Data and Nonce Value:  b'This is test for proof of work simulation.12564'
# Hash Data : c7c9406c85cea9130444f3e03a8da127d1d62021bff77d23169da1d0162590c0
# Data and Nonce Value:  b'This is test for proof of work simulation.12565'
# Hash Data : b81eb845034ae8f402b06430798ecfcdc4b80bb4983d7b172d396bda049ae9ec
# Data and Nonce Value:  b'This is test for proof of work simulation.12566'
# Hash Data : 52ecd70952be3254879d65f54ee31f8ba2e623a8dfe1032404ab9125c2a0f8f0
# Data and Nonce Value:  b'This is test for proof of work simulation.12567'
# Hash Data : 9b68cb9f16817af87cb4f6fa98aebcf294e1e76e465d4253add6c796d8f85ad0
# Data and Nonce Value:  b'This is test for proof of work simulation.12568'
# Hash Data : ea3a58d716610055cf7115563a145dd08430a524ba7225b0c316ffd759aa99bc
# Data and Nonce Value:  b'This is test for proof of work simulation.12569'
# Hash Data : 30ed4a6aee49524b8f4ee9e2798abbe0056f8a09124f227648dc70c104049d4d
# Data and Nonce Value:  b'This is test for proof of work simulation.12570'
# Hash Data : 1de5509f926ee154fbd3e2f55cc909020075a54ad0695fec324bbc8f137a0993
# Data and Nonce Value:  b'This is test for proof of work simulation.12571'
# Hash Data : 748b26458bb17befb4788be7c2a922589848c47755afb420c91caa390a9bb0f7
# Data and Nonce Value:  b'This is test for proof of work simulation.12572'
# Hash Data : 535a47066e682dea65be2375f45a8b8aa845924b6891c0fef4fd7e311a5de727
# Data and Nonce Value:  b'This is test for proof of work simulation.12573'
# Hash Data : 82c905c777ce1a516f8b8a730d64998fb63ee712c64c35f721006536acf216ed
# Data and Nonce Value:  b'This is test for proof of work simulation.12574'
# Hash Data : 8a0939cdc2fa1d7fdf72ac95ecd961aceec0ac5df0593332494236570922ac47
# Data and Nonce Value:  b'This is test for proof of work simulation.12575'
# Hash Data : 95b08c7a708b85a311f12e47b2d30a20075d3b8549a9b9ee750bbb744f96e27c
# Data and Nonce Value:  b'This is test for proof of work simulation.12576'
# Hash Data : 5d27845c78125b6c917860359e7211bd87ba0e5e07c276fd019f283331158bcc
# Data and Nonce Value:  b'This is test for proof of work simulation.12577'
# Hash Data : 10e8143e5c9230e5ad8dd664e51c66b6fe35e9ef86be32f0c9ed84b12cbd292f
# Data and Nonce Value:  b'This is test for proof of work simulation.12578'
# Hash Data : 3afc6f827d9f2865c6445ef684450d5c98ff13e144e56b8528f44243deeb30b8
# Data and Nonce Value:  b'This is test for proof of work simulation.12579'
# Hash Data : 2a62b350ff07e4457700bc7b76c007b9db2ba30a231cb69fcfa48ded5eaecedd
# Data and Nonce Value:  b'This is test for proof of work simulation.12580'
# Hash Data : 6b1a0d3e842747f83ba9ffbd80a8d12afc657ba6402ab99d5d174db15efcbd1d
# Data and Nonce Value:  b'This is test for proof of work simulation.12581'
# Hash Data : b42609a4435ca71c605a120181f2e77245d72578b56b1b30106c332c93cae0e2
# Data and Nonce Value:  b'This is test for proof of work simulation.12582'
# Hash Data : cf8f0d08a647f7385c449cd5f712be56d0d8953d36e8e2cfa785729f9c7cda94
# Data and Nonce Value:  b'This is test for proof of work simulation.12583'
# Hash Data : d352170d7d6517d73fcd9a427879a49dfbc724be4b5e2bf5928e79945f4ee53e
# Data and Nonce Value:  b'This is test for proof of work simulation.12584'
# Hash Data : 9d67396b86ff1dcc0c3525369014bc4a7f41696a4686bb3c9457f81c91729d7a
# Data and Nonce Value:  b'This is test for proof of work simulation.12585'
# Hash Data : 431dd45e98d7f1ee84b9d20bd02f3407fbb8ea7ed5e694589eff0e0eb8c09297
# Data and Nonce Value:  b'This is test for proof of work simulation.12586'
# Hash Data : 5a1c022c0917834deccfa0b0618b9bc8b8e2f2703350deb9bf47e46c15c998b3
# Data and Nonce Value:  b'This is test for proof of work simulation.12587'
# Hash Data : 0bb369e506c4aa85f9484c6131b8fb122cc8cbcdb543e890e72e1ea2cb5099a9
# Data and Nonce Value:  b'This is test for proof of work simulation.12588'
# Hash Data : 41520a88f4272a93ef6e9f20d380554cf55b7ade06e801fed64f0d4c1495c1b2
# Data and Nonce Value:  b'This is test for proof of work simulation.12589'
# Hash Data : 4d09b3aeeb5e11c965b80f7f7211514794285e669fd30c35f21e40eb44a47e1e
# Data and Nonce Value:  b'This is test for proof of work simulation.12590'
# Hash Data : 9a562b76a4cc9d75c6212c97c7b6b074e7ba0226cbec470c87f3fbf58354dfc1
# Data and Nonce Value:  b'This is test for proof of work simulation.12591'
# Hash Data : 7c4d436684ed00590acdf5017ae8ef364066fc4f7b7794bbf3dcf40885ee260d
# Data and Nonce Value:  b'This is test for proof of work simulation.12592'
# Hash Data : befd362f8856f2887b4e2f7db42a93408849e744fb574de325f376aab75fd008
# Data and Nonce Value:  b'This is test for proof of work simulation.12593'
# Hash Data : c1f5cab79bacef5a3d14f2c09afcb2ba2725a59acf8e05c2aede08ab1fad0036
# Data and Nonce Value:  b'This is test for proof of work simulation.12594'
# Hash Data : 61dccbd9dd89bf77099829543e93448423de1b000daa05af40ef7025d27db818
# Data and Nonce Value:  b'This is test for proof of work simulation.12595'
# Hash Data : cbe27b194f3f31ca9cfb206c1e8f1146e0ba6b42f02bd8ffb31c1e91051bb484
# Data and Nonce Value:  b'This is test for proof of work simulation.12596'
# Hash Data : 68110f69283a9a9ebd31ba0a07f21f54ecf3f399a1856aa40c45c0bb8bfab51c
# Data and Nonce Value:  b'This is test for proof of work simulation.12597'
# Hash Data : 01cff8b7dbdfb890748dac635626105a94c19bbaa651c5c7af5ccfd65414d28e
# Data and Nonce Value:  b'This is test for proof of work simulation.12598'
# Hash Data : 451f7df9c419212da392971517beb2982cf9d818a48c0f3a08f9be08104feac5
# Data and Nonce Value:  b'This is test for proof of work simulation.12599'
# Hash Data : d7fb34e3f5b57ad18313280abba47bfd3d2017ce4205a9ad0f46a5cecb579199
# Data and Nonce Value:  b'This is test for proof of work simulation.12600'
# Hash Data : 7fbf932ecf66b2de0ab5a1461ec28834f3308369f622bda3bb72e2a1cff1e595
# Data and Nonce Value:  b'This is test for proof of work simulation.12601'
# Hash Data : e3545cf6286add1dce5a57a0f6188e4b2bef45e68f44de4b0f74e0dc5328513c
# Data and Nonce Value:  b'This is test for proof of work simulation.12602'
# Hash Data : f3996e2a0698b27d6ad25268f1af1128391e4946e881ad6b27ce9902a1cf9975
# Data and Nonce Value:  b'This is test for proof of work simulation.12603'
# Hash Data : b3d9c0f790046c024997cf028005ab4b85b45044d75d2cc5a6fc49ecc5e39b06
# Data and Nonce Value:  b'This is test for proof of work simulation.12604'
# Hash Data : 75425773aae1e04fd5b0462bb8a5e9403f9dbc8d0e20ab202405825ea83b7063
# Data and Nonce Value:  b'This is test for proof of work simulation.12605'
# Hash Data : c50bc1d5f649859402c01fa0bde4b5bd68c8f64758aa707164779cdfdfcff83a
# Data and Nonce Value:  b'This is test for proof of work simulation.12606'
# Hash Data : bcc2b3b3c866d405be7f47375d31cf1c8ab4e78f894ad5678be6b772c6c88aba
# Data and Nonce Value:  b'This is test for proof of work simulation.12607'
# Hash Data : 5a5bb5a849e82b36435b29e024524f2f6825602cfb23d49444b16fe05dbef8f2
# Data and Nonce Value:  b'This is test for proof of work simulation.12608'
# Hash Data : 1634d934e609d9faa4351c250ab64ca415c78b6876b1f281a4f0804ec381c881
# Data and Nonce Value:  b'This is test for proof of work simulation.12609'
# Hash Data : 19ab766fc92b0184c6d0bc834b6b59430a4c6019bfc68b3ac1126acb853ebcc8
# Data and Nonce Value:  b'This is test for proof of work simulation.12610'
# Hash Data : 0713dc2acb65f4dea20b222d79a094f6504e556a37bdea0bf83431f11f8229d4
# Data and Nonce Value:  b'This is test for proof of work simulation.12611'
# Hash Data : e552b4b3995ea5b7dd98bd80f3b767395e17dede022aaf03db524c3bc1918bc9
# Data and Nonce Value:  b'This is test for proof of work simulation.12612'
# Hash Data : 778de4bd861eb37ad4f60ac1580afe6027b338430f378f3c44f4e41ed1600582
# Data and Nonce Value:  b'This is test for proof of work simulation.12613'
# Hash Data : 825f7fd3e80732b76de6d72e5957d763b680135afd956f48e70a04137dfba15f
# Data and Nonce Value:  b'This is test for proof of work simulation.12614'
# Hash Data : 330620a8359fb51b211d389aa96bc2847eae401524ea19fd6ea1871059d136c4
# Data and Nonce Value:  b'This is test for proof of work simulation.12615'
# Hash Data : 970ae41a791197b28b71aa4912d3365bcdde564e364593df1772cf8a24faea39
# Data and Nonce Value:  b'This is test for proof of work simulation.12616'
# Hash Data : 23df5e210bcca89242a975dcce7b66cae223b0467de297ad76de5a03b9ebc6c7
# Data and Nonce Value:  b'This is test for proof of work simulation.12617'
# Hash Data : 2046ab56b0aa28deb02ac691e2dfe48e7f1179209de8be52bdc5f3c3c5721255
# Data and Nonce Value:  b'This is test for proof of work simulation.12618'
# Hash Data : f07ce79f6cebe47122d504bfc54f174cb8a869c4ceff7086d9d52c241b109628
# Data and Nonce Value:  b'This is test for proof of work simulation.12619'
# Hash Data : cc4f2d4af06040c6c2883b61734f526e5a643fdf968638a90cd2283d5c2d666a
# Data and Nonce Value:  b'This is test for proof of work simulation.12620'
# Hash Data : f7de922b866402d2053003efbc78c59a15afc5cbfe8dd158756244b97c3b2fb6
# Data and Nonce Value:  b'This is test for proof of work simulation.12621'
# Hash Data : f26b421b8e688d346fb3baebd6e9430ef7ee0db0f3bd37a6121f07c11ccb0bc6
# Data and Nonce Value:  b'This is test for proof of work simulation.12622'
# Hash Data : 000157399fbcbe2b1c83db2bc44bb8be2333e7d438f6216ac9161892705a01d5
# Found a valid nonce (Encode Format): 12622
# Hash: 000157399fbcbe2b1c83db2bc44bb8be2333e7d438f6216ac9161892705a01d5

# %%
#
# Proof of Authority (PoW) Practice
#
# Proof of Authority (PoA) is a consensus mechanism used in blockchain networks 
# where the authority to validate transactions is given to a pre-selected group 
# of nodes. These nodes, called validators, are responsible for verifying transactions 
# and adding them to the blockchain.
#
# import the necessary libraries
import hashlib

# define the validator nodes
validators = ["node1", "node2", "node3"]

# define the blockchain as a list
# will simulate as if it's a blockchan trail
blockchain = []

# define a function to check if a node is a validator
def is_validator(node):
    if node in validators:
        return True
    else:
        return False

# define a function to validate a transaction
def validate_transaction(transaction, node):
    if is_validator(node):
        # calculate the hash of the transaction
        transaction_hash = hashlib.sha256(transaction.encode()).hexdigest()
        # add the transaction to the blockchain
        add_to_blockchain(transaction_hash)
        return True
    else:
        return False

# define a function to add a transaction to the blockchain
def add_to_blockchain(transaction_hash):
    # add the transaction to the blockchain
    blockchain.append(transaction_hash)

# test the code with positive case
transaction = "send 10 tokens from Alice to Bob"
node = "node1"
if validate_transaction(transaction, node):
    print("Transaction added to blockchain.")
else:
    print("Transaction rejected. Node {} is not a validator.".format(node))

# test the code with negative case
transaction = "send 10 tokens from Alice to Bob"
# Non validator node10 sending the requesting
node = "node10"
if validate_transaction(transaction, node):
    print("Transaction added to blockchain.")
else:
    print("Transaction rejected. Node {} is not a validator.".format(node))
# Out:
# Transaction added to blockchain.
# Transaction rejected. Node node10 is not a validator.

# %%
#
# Proof of Stake (PoS) Practice
#
# Proof of Stake (PoS) is a consensus mechanism used in blockchain networks where 
# the authority to validate transactions is determined by the amount of stake 
# (or resources) a node holds in the network.
#
# To DO:
# PoS also can account reputation, age of stake, and node performance
import random

# define the validator nodes
# also has the amount of stake hold by nodes
validators = {
    "node1": 250, 
    "node2": 251, 
    "node3": 700,
    "node4":1000
}

# define a function to validate a transaction
def validate_transaction(transaction):
    # Select a validator, higher the stake more chance to get minning opportunity
    total_stake = sum(validators.values())
    validator_stake = [stake/total_stake for stake in validators.values()]
    validator = random.choices(list(validators.keys()),weights=validator_stake)[0]
    # Calculate the hash of the transaction
    transaction_hash = hashlib.sha256(transaction.encode()).hexdigest()
    # Add the transaction to the blockchain
    add_to_blockchain(transaction_hash, validator)
    return validator

# define a function to add a transaction to the blockchain
def add_to_blockchain(transaction_hash, validator):
    # add the transaction to the blockchain
    blockchain.append({"hash": transaction_hash, "validator": validator})

# test the code
count = 0
while count<10:
  transaction = "send 10 tokens from Alice to Bob"
  validator = validate_transaction(transaction)
  print("Transaction added to blockchain by validator:", validator)
  count += 1
# Out:
# Transaction added to blockchain by validator: node2
# Transaction added to blockchain by validator: node1
# Transaction added to blockchain by validator: node4
# Transaction added to blockchain by validator: node4
# Transaction added to blockchain by validator: node3
# Transaction added to blockchain by validator: node1
# Transaction added to blockchain by validator: node4
# Transaction added to blockchain by validator: node4
# Transaction added to blockchain by validator: node4
# Transaction added to blockchain by validator: node2
